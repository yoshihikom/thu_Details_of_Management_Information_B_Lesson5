# %% [markdown]
# # 「Python による経済・経営分析のための実践的データサイエンス」第３章 (pp.47-54)

# %% [markdown]
# Pandas の read_html を用いたデータのスクレイピングについて、本では取り上げていない事例も含めてご紹介したいと思います。
# まず、Pandas をインポートし、2020年の紅白歌合戦の出場歌手と売上をまとめたページの tableタグの情報をまとめて取得したいと思います。

# %%
import pandas as pd

# SSL証明書が正しくないサイトに対してPythonでアクセスする
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
#

url1='https://www.wasteofpops.com/entry/2020/12/21/000000'
dfs2= pd.read_html(url1)

dfs2
# Out:
# [                    歌手名                 曲名           発表年(売上)
#  0                 あいみょん                裸の心  2020(561,514・合算)
#  1                 石川さゆり           天城越え(12)      1986(48,500)
#  2                  坂本冬美       ブッダのように私は死んだ       2020(9,400)
#  3                  櫻坂46     Nobody's fault  2020(425,800・合算)
#  4                  JUJU        やさしさで溢れるように      2009(18,400)
#  5              Superfly        愛をこめて花束を(2)      2008(46,700)
#  6                 天童よしみ          あんたの花道(3)     2002(114,000)
#  7                  東京事変            うるうるうるう        2020(アルバム)
#  8                 NiziU     Make you happy          2020(配信)
#  9                 乃木坂46          Route 246          2020(配信)
#  10              Perfume             （メドレー）               NaN
#  11                日向坂46            アザトカワイイ        2020(アルバム）
#  12               Foorin            パプリカ(2)     2018(176,900)
#  13            BABYMETAL        イジメ、ダメ、ゼッタイ      2013(24,100)
#  14                 松田聖子          瑠璃色の地球(3)        1986(アルバム)
#  15                MISIA             アイノカタチ      2018(46,700)
#  16                水森かおり            瀬戸内 小豆島      2020(29,200)
#  17                milet         inside you      2019(15,000)
#  18                 LiSA             （メドレー）               NaN
#  19  Little Glee Monster                 足跡      2020(19,200)
#  20                  NaN                NaN               NaN
#  21                    嵐             （メドレー）               NaN
#  22                五木ひろし              山河(2)      2000(61,300)
#  23                   瑛人                 香水  2019(660,466・合算)
#  24       Official髭男dism          I LOVE...  2020(878,500・合算)
#  25                関ジャニ∞          前向きスクリーム！     2015(318,100)
#  26           Kis-My-Ft2  We never give up!     2011(329,000)
#  27        King & Prince          I promise         2020（未集計）
#  28                 郷ひろみ             （メドレー）               NaN
#  29          GENERATIONS            YOU & I          2020（配信）
#  30                   純烈             愛をください      2020(50,000)
#  31                 鈴木雅之             夢で逢えたら     1996(439,600)
#  32             SixTones     Imitation Rain   2020(1,760,900)
#  33             Snow Man               D.D.   2020(1,760,900)
#  34                氷川きよし      限界突破×サバイバー(2)      2017(21,900)
#  35                 福山雅治            家族になろうよ     2011(321,900)
#  36       Hey! Say! JUMP             （メドレー）               NaN
#  37                  星野源             うちで踊ろう          2020(配信)
#  38         Mr. Children   Documentary film        2020(アルバム)
#  39                三山ひろし             北のおんな町      2020(24,200)
#  40                 山内惠介              恋する街角       2008(9,000)
#  41                   ゆず         雨のち晴レルヤ(2)      2013(73,500)]

# %% [markdown]
# データの正規化などは必要そうですが、出場歌手や曲名、売上や年の情報が取得できましたね。

# %% [markdown]
# 続いて、本でも取り上げているパチンコホールの営業状況について read_html を用いたスクレイピングコードを実行してみましょう。輪転機がまわる本の出版プロセスの間に、どうやらサイト構造が変化したようです。そこで、1. 本に掲載したソースコード, 2. 2021年2月段階のサイト構造に即し修正したソースコードの両方を掲載します。

# %% [markdown]
# ### 1. 本に掲載したソースコード

# %%
import pandas as pd
import numpy as np

list = ["hokkaido", "aomori","iwate", "miyagi", "akita", "yamagata", "fukushima", "ibaraki", "tochigi", "gunma",
        "saitama", "chiba", "tokyo", "kanagawa", "niigata", "toyama", "ishikawa","fukui", "yamanashi", "nagano", "gifu",
        "shizuoka", "aichi", "mie","shiga", "kyoto", "osaka", "hyogo", "nara", "wakayama", "tottori", "shimane", "okayama",
        "hiroshima", "yamaguchi", "tokushima", "kagawa", "ehime", "kochi", "fukuoka", "saga", "nagasaki", "kumamoto", "oita",
       "miyazaki", "kagoshima", "okinawa"]

#list = ["tokyo"]
print(list)
url1 = 'http://koko-pachi.com/htm/korona.' 

for j in range(len(list)):
    data3=pd.DataFrame()
    print(list[j])
    url2 = list[j]+".5.htm"
    url3=url1+url2
    #print(url3)
    dfs= pd.read_html(url3)
    data3=data3.append(dfs)
    
    #data3
    #print(data3)
    #データ整理用
    #簡易的にラベルを付与する
    data3.columns={'A','B','C','D','E','F', 'G', 'H'}
    
    #不要な行を削除する
    #data3=data3.dropna(how='all', axis=1)
    #data3=data3.dropna(how='any')
    data3=data3.drop('D', axis=1)
    data3=data3.drop('E', axis=1)
    data3=data3.drop('F', axis=1)
    data3=data3.drop('G', axis=1)
    data3=data3.drop('H', axis=1)
    data3=data3.drop('B', axis=1)
    data3=data3.drop('A', axis=1)
    data3=data3.dropna(how='any')
   

    #データの整理. 余計な箇所を削除する
    temp1=data3.loc[[0]]
    temp1.reset_index(drop=True, inplace=True)
    temp1.drop(temp1.tail(1).index, inplace=True)
    temp1.drop(temp1.head(1).index, inplace=True)
    temp1.drop(temp1.head(1).index, inplace=True)
    temp1.reset_index(drop=True, inplace=True)

    #データの整理. index を並べ直して, データを取り出す.
    temp2=data3.loc[[1]]
    temp2.reset_index(drop=True, inplace=True)
    temp3=data3.loc[[2]]
    temp3.reset_index(drop=True, inplace=True)
    
    data5=pd.concat([temp1,temp2,temp3], axis=1)
    
    label="pachinko_"+list[j]+"_20200609.csv"
    data5.to_csv(label)

# %% [markdown]
# ### 2021年2月段階のサイト構造に即し修正したソースコード

# %%
import pandas as pd
import numpy as np

list = ["hokkaido", "aomori","iwate", "miyagi", "akita", "yamagata", "fukushima", "ibaraki", "tochigi", "gunma",
        "saitama", "chiba", "tokyo", "kanagawa", "niigata", "toyama", "ishikawa","fukui", "yamanashi", "nagano", "gifu",
        "shizuoka", "aichi", "mie","shiga", "kyoto", "osaka", "hyogo", "nara", "tottori", "shimane", "okayama",
        "hiroshima", "yamaguchi", "tokushima", "kagawa", "ehime", "kochi", "fukuoka", "saga", "nagasaki", "kumamoto", "oita",
       "miyazaki", "kagoshima", "okinawa"]

list = ["tokyo"]

#どうやら和歌山だけサイト構造が他の都道府県と違うので、listから一時的に除外する
#list2 = ["wakayama"]

print(list)
url1 = 'http://koko-pachi.com/htm/korona.' 

for j in range(len(list)):
    data3=pd.DataFrame()
    print(list[j])
    #全体の営業状況のページが 5.htm から 6.htm に変更されているので修正
    url2 = list[j]+".6.htm"
    url3=url1+url2
    #print(url3)
    dfs= pd.read_html(url3)
    print(dfs)
    data3=data3.append(dfs)
#    pd.concat([data3,dfs])
    
#    data3
#    print(data3)
    #データ整理用
    #簡易的にラベルを付与する
    data3.columns={'A','B','C','D','E','F', 'G'}
    
    #不要な行を削除する
    # dropnaは NoN のある行を削除（axis=0は列、1は行）
    #（allはすべてNoN、anyは１つでもNoNがあれば）
    data3=data3.dropna(how='all', axis=1)
    #data3=data3.dropna(how='any')
    data3=data3.drop('D', axis=1)
    data3=data3.drop('E', axis=1)
    data3=data3.drop('F', axis=1)
    data3=data3.drop('G', axis=1)
    data3=data3.drop('C', axis=1)
    #data3=data3.drop('H', axis=1)
    data3=data3.drop('B', axis=1)
    #data3=data3.drop('A', axis=1)
    #data3=data3.dropna(how='any')
    print(data3)

    #データの整理. 余計な箇所を削除する
    temp1=data3.loc[[0]]
    temp1.reset_index(drop=True, inplace=True)
    #temp1.drop(temp1.tail(1).index, inplace=True)
    #temp1.drop(temp1.head(1).index, inplace=True)
    #temp1.drop(temp1.head(1).index, inplace=True)
    #temp1.reset_index(drop=True, inplace=True)

    #データの整理. index を並べ直して, データを取り出す.
    temp2=data3.loc[[1]]
    temp2.reset_index(drop=True, inplace=True)
    temp3=data3.loc[[2]]
    temp3.reset_index(drop=True, inplace=True)
    
    data5=pd.concat([temp1,temp2,temp3], axis=1)
    #data5.reset_index(drop=True, inplace=True)
    data5.columns=['住所','店名','状態']
    data5=data5.dropna(how='any')
    
    label="pachinko_"+list[j]+"_20210215.csv"
    data5.to_csv(label)
# Out:
# ['tokyo']
# tokyo
# [                     0
# 0  ここって昔はパチンコ屋？(ここパチ？),         0     1     2       3      4     5       6
# 0  再開 712  営業 0  不明 9  休業 712  閉店 23  待機 0  全部 744,      0                                                  1
# 0   番号                                         住所/ホール名/状態
# 1    1  東京都あきる野市秋川2-1-7オリエント 秋川店休業(2020/04/11〜2020/05/...
# 2    2  東京都あきる野市小川東1-5-1デルパラビルデルパラ6 あきる野店休業(2020/04/27...
# 3    3  東京都あきる野市下代継44-1パーク 秋川店休業(2020/04/11〜2020/05/25...
# 4    4  東京都稲城市矢野口313-7三慶ビル第一ホール 矢野口店休業(2020/04/11〜2020...
# 5    5  東京都羽村市五ノ神4-14-6オゼック 羽村店休業(〜2020/05/25)、再開(2020...
# 6    6  東京都羽村市羽東1-20-1トワーズ 羽村駅前店休業(2020/04/11〜2020/05/...
# 7    7  東京都羽村市神明台4-2-1トワーズ 羽村店休業(2020/04/11〜2020/05/25...
# 8    8  東京都羽村市小作台3-23-12トワーズ 小作駅前店休業(2020/04/11〜2020/0...
# 9    9  東京都葛飾区青戸3-31-8青松ビル(S)遊劇場3 青戸店休業(2020/04/11〜202...
# 10  10  東京都葛飾区青戸3-31-7(S)遊劇場4 青戸店休業(2020/04/11〜2020/06...
# 11  11  東京都葛飾区新小岩1-41-4NTビルD'ステーション 新小岩店休業(2020/04/08〜...
# 12  12  東京都葛飾区新小岩1-31-5マックスビルMAX-1 新小岩店休業(2020/04/08〜2...
# 13  13  東京都葛飾区東立石3-36-3 森永ハイム立石あかね 立石店休業(2020/04/23〜20...
# 14  14  東京都葛飾区亀有5-33-2アカデミー 亀有店休業(2020/04/11〜2020/05/2...
# 15  15  東京都葛飾区亀有5-32-5アクセル 亀有店休業(2020/04/23〜2020/05/25...
# 16  16  東京都葛飾区亀有3-22-1アトラス 亀有店休業(2020/04/08〜2020/05/25...
# 17  17  東京都葛飾区亀有5-37-10ハイツBIG-1アムディ 亀有店休業(2020/04/30〜2...
# 18  18  東京都葛飾区西新小岩1-9-8アラジン 新小岩店休業(〜2020/05/26)、再開(202...
# 19  19  東京都葛飾区西新小岩1-10-1日拓新小岩駅前ビルエスパス日拓1300 新小岩北口駅前店休業...
# 20  20  東京都葛飾区立石7-2-9オーパス・ワン 立石店休業(2020/04/11〜2020/05/...
# 21  21  東京都葛飾区東金町1-42-5豊勢金町ビルサイバー 金町北口店休業(2020/04/08〜2...
# 22  22  東京都葛飾区新小岩1-30-4ジャンボ 新小岩店休業(〜2020/05/26)、再開(202...
# 23  23  東京都葛飾区小菅4-10-8センチュリー 綾瀬店休業(2020/04/22〜2020/05/...
# 24  24                               東京都葛飾区亀有5-31-9マリトモビル,                                            0
# 0                            東京都あきる野市秋川2-1-7
# 1                                  オリエント 秋川店
# 2  休業(2020/04/11〜2020/05/29)、再開(2020/05/30〜),                  0
# 0  東京都あきる野市秋川2-1-7,            0
# 0  オリエント 秋川店,                                            0
# 0                     東京都あきる野市小川東1-5-1デルパラビル
# 1                                デルパラ6 あきる野店
# 2  休業(2020/04/27〜2020/05/08)、再開(2020/05/09〜),                   0       1
# 0  東京都あきる野市小川東1-5-1  デルパラビル,              0
# 0  デルパラ6 あきる野店,                                            0
# 0                            東京都あきる野市下代継44-1
# 1                                    パーク 秋川店
# 2  休業(2020/04/11〜2020/05/25)、再開(2020/05/26〜),                  0
# 0  東京都あきる野市下代継44-1,          0
# 0  パーク 秋川店,                                            0
# 0                         東京都稲城市矢野口313-7三慶ビル
# 1                                 第一ホール 矢野口店
# 2  休業(2020/04/11〜2020/05/26)、再開(2020/05/27〜),                 0     1
# 0  東京都稲城市矢野口313-7  三慶ビル,             0
# 0  第一ホール 矢野口店,                                  0
# 0                  東京都羽村市五ノ神4-14-6
# 1                         オゼック 羽村店
# 2  休業(〜2020/05/25)、再開(2020/05/26〜),                  0
# 0  東京都羽村市五ノ神4-14-6,           0
# 0  オゼック 羽村店,                                            0
# 0                             東京都羽村市羽東1-20-1
# 1                                 トワーズ 羽村駅前店
# 2  休業(2020/04/11〜2020/05/25)、再開(2020/05/26〜),                 0
# 0  東京都羽村市羽東1-20-1,             0
# 0  トワーズ 羽村駅前店,                                            0
# 0                             東京都羽村市神明台4-2-1
# 1                                   トワーズ 羽村店
# 2  休業(2020/04/11〜2020/05/25)、再開(2020/05/26〜),                 0
# 0  東京都羽村市神明台4-2-1,           0
# 0  トワーズ 羽村店,                                            0
# 0                           東京都羽村市小作台3-23-12
# 1                                 トワーズ 小作駅前店
# 2  休業(2020/04/11〜2020/05/25)、再開(2020/05/26〜),                   0
# 0  東京都羽村市小作台3-23-12,             0
# 0  トワーズ 小作駅前店,                                            0
# 0                         東京都葛飾区青戸3-31-8青松ビル
# 1                                (S)遊劇場3 青戸店
# 2  休業(2020/04/11〜2020/05/19)、再開(2020/05/20〜),                 0     1
# 0  東京都葛飾区青戸3-31-8  青松ビル,              0
# 0  (S)遊劇場3 青戸店,                                            0
# 0                             東京都葛飾区青戸3-31-7
# 1                                (S)遊劇場4 青戸店
# 2  休業(2020/04/11〜2020/06/25)、再開(2020/06/26〜),                 0
# 0  東京都葛飾区青戸3-31-7,              0
# 0  (S)遊劇場4 青戸店,                                            0
# 0                        東京都葛飾区新小岩1-41-4NTビル
# 1                              D'ステーション 新小岩店
# 2  休業(2020/04/08〜2020/05/25)、再開(2020/05/26〜),                  0     1
# 0  東京都葛飾区新小岩1-41-4  NTビル,                0
# 0  D'ステーション 新小岩店,                                            0
# 0                      東京都葛飾区新小岩1-31-5マックスビル
# 1                                 MAX-1 新小岩店
# 2  休業(2020/04/08〜2020/05/25)、再開(2020/05/26〜),                  0       1
# 0  東京都葛飾区新小岩1-31-5  マックスビル,             0
# 0  MAX-1 新小岩店,                                            0
# 0                    東京都葛飾区東立石3-36-3 森永ハイム立石
# 1                                    あかね 立石店
# 2  休業(2020/04/23〜2020/06/12)、再開(2020/06/13〜),                          0
# 0  東京都葛飾区東立石3-36-3 森永ハイム立石,          0
# 0  あかね 立石店,                                            0
# 0                             東京都葛飾区亀有5-33-2
# 1                                  アカデミー 亀有店
# 2  休業(2020/04/11〜2020/05/25)、再開(2020/05/26〜),                 0
# 0  東京都葛飾区亀有5-33-2,            0
# 0  アカデミー 亀有店,                                            0
# 0                             東京都葛飾区亀有5-32-5
# 1                                   アクセル 亀有店
# 2  休業(2020/04/23〜2020/05/25)、再開(2020/05/26〜),                 0
# 0  東京都葛飾区亀有5-32-5,           0
# 0  アクセル 亀有店,                                            0
# 0                             東京都葛飾区亀有3-22-1
# 1                                   アトラス 亀有店
# 2  休業(2020/04/08〜2020/05/25)、再開(2020/05/26〜),                 0
# 0  東京都葛飾区亀有3-22-1,           0
# 0  アトラス 亀有店,                                            0
# 0                    東京都葛飾区亀有5-37-10ハイツBIG-1
# 1                                   アムディ 亀有店
# 2  休業(2020/04/30〜2020/05/19)、再開(2020/05/20〜),                  0         1
# 0  東京都葛飾区亀有5-37-10  ハイツBIG-1,           0
# 0  アムディ 亀有店,                                  0
# 0                  東京都葛飾区西新小岩1-9-8
# 1                        アラジン 新小岩店
# 2  休業(〜2020/05/26)、再開(2020/05/27〜),                  0
# 0  東京都葛飾区西新小岩1-9-8,            0
# 0  アラジン 新小岩店,                                            0
# 0                  東京都葛飾区西新小岩1-10-1日拓新小岩駅前ビル
# 1                        エスパス日拓1300 新小岩北口駅前店
# 2  休業(2020/04/08〜2020/05/28)、再開(2020/05/29〜),                   0          1
# 0  東京都葛飾区西新小岩1-10-1  日拓新小岩駅前ビル,                      0
# 0  エスパス日拓1300 新小岩北口駅前店,                                            0
# 0                              東京都葛飾区立石7-2-9
# 1                                オーパス・ワン 立石店
# 2  休業(2020/04/11〜2020/05/14)、再開(2020/05/15〜),                0
# 0  東京都葛飾区立石7-2-9,              0
# 0  オーパス・ワン 立石店,                                            0
# 0                      東京都葛飾区東金町1-42-5豊勢金町ビル
# 1                                 サイバー 金町北口店
# 2  休業(2020/04/08〜2020/05/25)、再開(2020/05/26〜),                  0       1
# 0  東京都葛飾区東金町1-42-5  豊勢金町ビル,             0
# 0  サイバー 金町北口店,                                  0
# 0                  東京都葛飾区新小岩1-30-4
# 1                        ジャンボ 新小岩店
# 2  休業(〜2020/05/26)、再開(2020/05/27〜),                  0
# 0  東京都葛飾区新小岩1-30-4,            0
# 0  ジャンボ 新小岩店,                                            0
# 0                             東京都葛飾区小菅4-10-8
# 1                                 センチュリー 綾瀬店
# 2  休業(2020/04/22〜2020/05/26)、再開(2020/05/27〜),                 0
# 0  東京都葛飾区小菅4-10-8,             0
# 0  センチュリー 綾瀬店,                       0
# 0  東京都葛飾区亀有5-31-9マリトモビル,                 0       1
# 0  東京都葛飾区亀有5-31-9  マリトモビル]
#          A
# 0      NaN
# 0   休業 712
# 0      NaN
# 1      NaN
# 2      NaN
# ..     ...
# 2      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
#
# [144 rows x 1 columns]
# C:\Users\murakawa\AppData\Local\Temp\ipykernel_26148\2116053877.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data3=data3.append(dfs)

# %% [markdown]
# 本にも書きましたが、Web 空間上のサイトの構造はデザインや内容の変更に従い変化していきます。そのため、本に書いてあるスクレイピングの手法はあくまで一例として捉えて頂けると助かります。上記のソースコードもありますように、table タグをメインに構成されている Web サイトの場合には、Pandas の read_html を用いてまずはデータを取得し、Pandas のコードを組み合わせることで、自らが利用する情報にデータを整形することが必要不可欠な作業になるかと思います。

# %% [markdown]
# 参考文献
# - pandas read_html; https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_html.html
